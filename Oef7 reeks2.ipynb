# %% [markdown]
# https://www.youtube.com/watch?v=kx2GzBeGPco

# %%
from sympy import *
init_printing()
x, y, z, u, v, r = symbols('x y z u v r')
alpha1, beta, omega_21 = symbols('alpha1 beta omega_2_1')
x, y, z, alpha1, beta, omega_21
# Out:
# (x, y, z, α₁, β, ω₂ ₁)

# %%
# x,y,z,r uitrekennen 
EQ1 = Eq((1+r)**2+(r)**2+(4+r)**2 -2*(1+r)-2*r-2*(4+r)-22,0 )
display(EQ1)
# alls r -3 is dan is A =(-2,-3,1)
# als r 5/3 is dan is B = (2.67,1.67,5.67)
# het middelpunt van de bol = (1,1,1)
# raaklijn opstellen formule (0=(Ax-m)*(x-Ax)+(Ay-m)*(y+Ay)+(Az-m)*(z-Az))
# dan bekom je voor de raaklijn van A met de bol -3x-4y-18=0
# en voor de raaklijn van B met de bol 1,67x+0,67y+4,67z-32,0389=0
solve(EQ1,r)
# Out:
#  2                2          2
# r  - 6⋅r + (r + 1)  + (r + 4)  - 32 = 0
# [-3, 5/3]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Maak een meshgrid voor de hoeken theta en phi voor de bol
theta = np.linspace(0, 2 * np.pi, 100)
phi = np.linspace(0, np.pi, 100)

# Stel de straal van de bol in
r = 5

# Parametrische vergelijkingen voor de bol
x = r * np.outer(np.cos(theta), np.sin(phi))
y = r * np.outer(np.sin(theta), np.sin(phi))
z = r * np.outer(np.ones(np.size(theta)), np.cos(phi))

# Maak de plot voor de bol
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, color='b', alpha=0.6, rstride=5, cstride=5)

# Punt A (-2, -3, 1)
ax.scatter(-2, -3, 1, color='r', s=100, label='Punt A (-2, -3, 1)')

# Punt B (2.67, 1.67, 4.67)
ax.scatter(2.67, 1.67, 4.67, color='g', s=100, label='Punt B (2.67, 1.67, 5.67)')

# Labels voor assen
ax.set_xlabel('X-as')
ax.set_ylabel('Y-as')
ax.set_zlabel('Z-as')

# Voeg een legende toe
ax.legend()

# Vlak 1: -3x - 4y - 18 = 0
# Kies een bereik voor x en y
xx, yy = np.meshgrid(np.linspace(-10, 10, 100), np.linspace(-10, 10, 100))
zz1 = np.full_like(xx, -18/0.01)  # Plat vlak (parallel aan z-as)

# Plot het eerste vlak
ax.plot_surface
# Vlak 2: 1.67x + 0.67y + 4.67z - 32.0389 = 0
# Bereken het z-vlak op basis van de meshgrid
zz2 = (32.0389 - 1.67*xx - 0.67*yy) / 4.67
